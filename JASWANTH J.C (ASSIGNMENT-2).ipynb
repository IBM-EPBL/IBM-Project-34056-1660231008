# %% [markdown]
# |                                                                                               |
# |-----------------------------------------------------------------------------------------------|
# | import pandas as pd import numpy as np import matplotlib. pyplot as plt import seaborn as sns |
#
# In \[ 26\] :
#
# <table>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image1.jpeg" style="width:0.32153in;height:0.125in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td>df=pd. read_csv( 'Churn Modelling.</td>
# <td>)</td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image2.jpeg" style="width:10.29583in;height:0.30278in" />
#
# Out \[28\] : RowNumber Customerld Surname CreditScore Geography Gender
# Age Tenure Balance NumOfProducts HasCrCard IsActiveMember
#
# Hargrave1
#
# 1.  2 15647311 Hill 608 Spain Female 41 1 83807.86 1
#
# 2.  3 15619304 Onio 502 France Female 42 8 159660.80 3 1
#
# 3.  4 15701354 Boni 699 France Female 39 1 0.00 2
#
# 4.  5 15737888 Mitchell 850 Spain Female 43 2 125510.82 1 1
#
# 5.  9996 15606229 Obijiaku 771 France
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image3.jpeg" style="width:0.25972in" />
#     39 5 0.00 2
#
# 6.  9997 15569892 Johnstone 516 France Male 35 10 57369.61 1 1
#
# 7.  9998 15584532 Liu 709 France Female 36 7 0.00 1
#
# 8.  9999 15682355 Sabbatini 772 Germany Male 42 3 75075.31 2 1
#
# 9.  10000 15628319 Walker 792 France Female 28 4 130142.79 1
#
# 10. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image4.jpeg" />
#
# 11. rows x 14 columns
#
# 12. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image5.jpeg" />
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image6.jpeg" style="width:8.80694in;height:0.17778in" />
#
# |           |            |         |             |           |        |     |        |         |               |           |                |        |
# |-----------|------------|---------|-------------|-----------|--------|-----|--------|---------|---------------|-----------|----------------|--------|
# | df.head() |            |         |             |           |        |     |        |         |               |           |                |        |
# | RowNumber | Customerld | Surname | CreditScore | Geography | Gender | Age | Tenure | Balance | NumOfProducts | HasCrCard | IsActiveMember | Estima |
#
# In \[ 29\] :
#
# Out \[29\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image7.jpeg" />
# 1 5634602 Hargrave 619 France Female 42 2 0.00 1 1
#
# 1.  2 1 5647311 608 Spain Female 41
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image8.jpeg" />
#     83807.86
#
# 2.  3 15619304 Onio 502 France Female 42 8 159660.80 3
#
# 3.  4 15701354 Boni 699 France Female 39 0.00 2
#
# 4.  5 15737888 Mitchell 850 Spain Female 43 2 125510.82 1 1
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image9.jpeg" style="width:9.00417in;height:0.17778in" />
#
# |           |
# |-----------|
# | df. shape |
#
# In \[3ê\] :
#
# (løeøø, 14)
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image10.jpeg" style="width:0.56667in;height:0.12014in" />
#
# In \[ 31\] :
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image11.jpeg" style="width:9.64306in;height:0.64306in" />
#
# |                                                                                                                                                                                                                                                                                                                                                |
# |------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | france\['Balance'plt.plot(df france\[ 'Balance' \] ) ' PI t. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image12.jpeg" style="width:1.04236in;height:0.125in" />Balance ' ' Balance \] ) , 'o plt.plot(df_germany\[ 'Balance' \] , np.zeros like(df_germany\[ 'Balance \] ) , 'o' ) plt.xlabel( ' Age' ) PI t. show() |
#
# In \[ 32\] :
#
# 50000100000150000200000250000
#
# Age
#
# In \[33\] : sns. FacetGrid (df , hue= "Geography" , height=5) . map(plt.
# scatter, " Age" , " Balance" ) . add_legend ( ) ; PI t. show()
#
# 250000
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image13.jpeg" style="width:0.11528in;height:0.55694in" />
#
# 200000
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image14.jpeg" style="width:4.36528in;height:4.51944in" />
#
# 150000
#
# Geography
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image15.jpeg" />France
#
# Spain
#
# 100000
#
# Germany
#
# 50000
#
# <table>
# <tbody>
# <tr class="odd">
# <td>20</td>
# <td><p>40</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image16.jpeg" /></p></td>
# <td><p>60</p>
# <p>Age</p></td>
# <td>80</td>
# </tr>
# </tbody>
# </table>
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image17.jpeg" style="width:0.32153in;height:0.125in" />
# sns. pairplot (df, hue= "Gender" , height=3)
#
# \<seaborn.axisgrid.PairGrid at ex1f62cd291ØØ\> OUt\[34\] :
#
# 1.580
#
# 1.575
#
# 1.570 d 1565
#
# 1560
#
# 750000
#
# Gendeg
#
# 100000
#
# 125000
#
# 25000
#
# 0 2500 7500 10000 25 50 7.5 10ocoo 200000 o "00000001500omoooo rnOtprodu
# SAC
#
# |           |            |         |             |           |        |     |        |         |               |           |                |        |
# |-----------|------------|---------|-------------|-----------|--------|-----|--------|---------|---------------|-----------|----------------|--------|
# | df.head() |            |         |             |           |        |     |        |         |               |           |                |        |
# | RowNumber | Customerld | Surname | CreditScore | Geography | Gender | Age | Tenure | Balance | NumOfProducts | HasCrCard | IsActiveMember | Estima |
#
# In \[35\] :
#
# Out\[35\]
#
# <table>
# <tbody>
# <tr class="odd">
# <td></td>
# <td>1 5634602 Hargrave 619 France Female 42 0.00 1 5647311 608 Spain Female 41 83807.86 15619304 Onio 502 France Female 42 8 159660.80 15701354 Boni 699 France Female 39 0.00 1 5737888 Mitchell 850 Spain Female 43 2 125510.82</td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In</td>
# <td><p>df.mean()</p>
# <p>C:\Users\DWARAKESWARAN U\AppData\Loca1\Temp\ipykerne1 FutureWarning: Dropping of nuisance columns in Data</p></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>Frame reductions (with 'numeric only=None' ) is deprecated; in a future version this will raise TypeError. umns before calling the reduction. df. mean()</td>
# <td>Select only valid col</td>
# </tr>
# <tr class="even">
# <td>Out [36] :</td>
# <td><p>RowNumber 5. eeøseee+ê3 Customerld 1 .56904e07 CreditScore 6.95288e+ê2</p>
# <p>Age 3 .89218ee+ô1 Tenure 5.6128øeeoø Balance 7 .648589e+Ø4</p>
# <p>NumOfProducts 1.53ê2øee+eø</p>
# <p>HasCrCard</p>
# <p>IsActiveMember 5.151eøee-ø1 EstimatedSa1ary 1. eeø962e+65</p>
# <p>Exited 2. e-37eøee-ê1 dtype: float64</p></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# df.mean(axis=l)
#
# C:\\Users\\DWARAKESWARAN U\\AppData\\Loca1\\Temp\\ipykerne1
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image18.jpeg" style="width:1.61806in;height:0.12014in" />
# FutureWarning: Dropping of nuisance columns in Data
#
# Frame reductions (with 'numeric_on1y=None' ) is deprecated; in a future
# version this will raise TypeError. Select only valid col umns before
# calling the reduction.
#
# df.<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image19.jpeg" style="width:0.87431in;height:0.125in" />
#
# 1.436662e+Ø6
#
# Out \[37\] :
#
# 1
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image20.jpeg" style="width:0.87847in" />
#
# -   1.44486Øe+Ø6
#
# -   1 .435993e+Ø6
#
# -   1.449399e06
#
# -   1.428483e+Ø6
#
# -   1.43Ø866e+Ø6
#
# -   1.421579e+66
#
# -   1.441922e+Õ6
#
# -   1.437Ø44e+Ø6
#
# Length : løeøø, dtype: float64
#
# In \[38\] : df.median()
#
# C:
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image21.jpeg" style="width:5.35417in;height:0.125in" />
# FutureWarning: Dropping of nuisance columns in DataF rame reductions
# (with 'numeric only=None' ) is deprecated; in a future version this will
# raise TypeError. Select only valid colu mns before calling the
# reduction. df. median()
#
# RowNumber 5. eee5eøe03 Out \[38\] :
#
# Customerld 1 .569e74e+ê7 CreditScore 6.52øeøee02
#
# Age 3.7øøøeee+ê1 Tenure 5. eeeeeeeoø Balance 9 .719854e+Ø4
#
# NumOfProducts 1. øeøeøeeoø HasCrCard 1. eeøøeee+eø
#
# IsActiveMember 1. eeeeeee+eø EstimatedSa1ary 1 .019-39e+Ø5 Exited e.
# eeeøeee+eø dtype: float64
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>norm data pd. Data Frame (np. random. normal (size=løeøeø) )</p>
# <p>norm data. 16));,</p>
# <p>PI t. vlines (norm_data . mean ( ) yrnin=e, ymax=e.4, linewidth=5 6)<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image22.jpeg" /></p>
# <p>PI t. vlines (norm_data . median( ) , ymin=e, ymax=e.4, linewidth=2<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image23.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image24.jpeg" />color:" red " ) ;</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[39\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image25.jpeg" style="width:8.74514in;height:8.32292in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>skewed data - pd.DataFrame(np.random.exponentia1(size--leeeeø) )</p>
# <p>skewed <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image26.jpeg" style="width:1.77708in;height:0.45625in" /> ,</p>
# <p>plt.vlines(skewed data.mean(), ymin=e, ymax=e.8, linewidth=5. ê) ;</p>
# <p>plt.vlines(skewed data. median(), ymin=e, ymax=e. 8, linewidth=2. e, color:" red " ) ;</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[4Ø\] :
#
# 5
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>norm data = np. random.<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image27.jpeg" style="width:1.09028in;height:0.12986in" /></p>
# <p>outliers np.random.norma1(15, size=3) combined data - pd.DataFrame(np.concatenate((norm data,</p>
# <p>combined data. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image28.jpeg" style="width:1.39236in;height:0.47014in" /> ,</p>
# <p>plt.vlines(combined data. mean(), yrnin=e, ymax=e. 2, linewidth=5. e) ;</p>
# <p>pit. v lines (combined data. median(), ymin=e, ymax=e. 2, linewidth=2. e, color:" red " ) ;</p></td>
# <td>outliers),</td>
# <td>axis=Ø) )</td>
# </tr>
# </tbody>
# </table>
#
# In \[41\] :
#
# -551015200.200
#
# 0.175
#
# 0.150
#
# o\. 125
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image29.jpeg" />
# o. 100 8
#
# 0.075
#
# 0.050
#
# 0.025
#
# o.ooo
#
# |            |            |         |             |           |        |     |        |         |               |           |                |       |
# |------------|------------|---------|-------------|-----------|--------|-----|--------|---------|---------------|-----------|----------------|-------|
# | df. mode() |            |         |             |           |        |     |        |         |               |           |                |       |
# | RowNumber  | Customerld | Surname | CreditScore | Geography | Gender | Age | Tenure | Balance | NumOfProducts | HasCrCard | IsActiveMember | Estir |
#
# In \[42\] :
#
# Out \[42\] :
#
# 1 15565701 Smith 850.0 France
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image30.jpeg" style="width:0.25972in" />
# 37.0 2.0 0.0 1.0 1.0 1.0
#
# -   2 15565706 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   3 15565714 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   4 15565779 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   5 15565796 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   9996 15815628 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   9997 15815645 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   9998 15815656 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   9999 15815660 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   10000 15815690 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# -   rows x 14 columns
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image31.jpeg" style="width:8.91319in;height:0.17778in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image32.jpeg" style="width:0.56181in;height:0.12014in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td><p>five num</p>
# <p>five num</p></td>
# <td><p>[df[" Age" ] . quanti1e(Ø) ,</p>
# <p>" Age"] . quanti1e(Ø.25) , " Age" ] . quanti1e(Ø.56) , df[" Age" ] . quanti1e(Ø.75) ,</p>
# <p>" Age quantile(l)]</p></td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# \[18.e, 32.e, 37.e, 44.e, 920\] Out \[43\] :
#
# |                       |
# |-----------------------|
# | "Age" \] . describe() |
#
# In \[44\] :
#
# <table>
# <tbody>
# <tr class="odd">
# <td>Out [44] :</td>
# <td>count</td>
# <td>leøeø. øeøeøe</td>
# </tr>
# <tr class="even">
# <td></td>
# <td>mean</td>
# <td>38. 92180</td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>std</td>
# <td>16.48706</td>
# </tr>
# <tr class="even">
# <td></td>
# <td>min</td>
# <td>18. eeeeøe</td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>25%</td>
# <td><p>32. øeøeøe</p>
# <p>37. øeøeøe</p></td>
# </tr>
# <tr class="even">
# <td></td>
# <td>75%</td>
# <td>44. øeøeøe</td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>max</td>
# <td>92. eeeeøe</td>
# </tr>
# <tr class="even">
# <td></td>
# <td>Name: Age, dtype: float64</td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# |                                                                                                                                                 |                          |
# |-------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------|
# | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image33.jpeg" style="width:0.64306in;height:0.125in" /> . quanti1e(Ø.75) - | "Age"\] . quanti1e(Ø.25) |
#
# In \[45\] :
#
# |              |      |
# |--------------|------|
# | Out \[45\] : | 12.6 |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>df. boxplot ( column= " Age " , return type= axes ' figsize=(8,8) )</p>
# <p>PI t. 74, y=22.25, <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image34.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image35.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image36.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image37.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image38.jpeg" /> Quartile")</p>
# <p>PI t. text (x- y=18.75, s= " Median " ) pit. text e. 75, Y=15. 5, s="lst Quartile") PI t. text (x=e.9, y=1Ø, s="Min")</p>
# <p>PI t. text (x- <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image39.jpeg" /> Y-33.5, s="Max")</p>
# <p>PI t. text (x--9.7, Y=19.5, <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image40.jpeg" style="width:0.56181in;height:0.12014in" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image41.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image42.jpeg" /> rotation=9ê,</p></td>
# <td>size=25);</td>
# </tr>
# </tbody>
# </table>
#
# In \[46\] :
#
# AgeMin90807060504020
#
# In \[47\] : "Age"\] .var()
#
# |              |                    |
# |--------------|--------------------|
# | Out \[47\] : | 169.99468416841645 |
#
# In \[48\] : "Age"\] . std()
#
# |     |     |                    |
# |-----|-----|--------------------|
# | Out | :   | le. 487064517e4591 |
#
# In \[49\] : abs median devs abs (df\[ "Age " \] - df\["Age"\] .
# median()) abs median devs.median() \* 1.4826
#
# |     |     |        |
# |-----|-----|--------|
# | Out | :   | 8.8956 |
#
# In \[59\] : "Age"\] . skew()
#
# |              |                     |
# |--------------|---------------------|
# | out \[5ê\] : | 1 .6113262636234552 |
#
# In \[51\] : "Age"\] . kurt( )
#
# 1.395347e61506956 Out \[51\] :
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>norm data np. skewed data</p>
# <p>uniform data peaked data</p>
# <p>data df - pd .</p>
# <p>data <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image43.jpeg" style="width:0.73958in;height:0.12986in" /></p></td>
# <td><p>random. normal ( size=løøeøe)</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image44.jpeg" style="width:3.39514in;height:0.12986in" /></p>
# <p>np. random. exponential (size-65(30) ) , axis=Ø) np.random.uniform(e,2, size=leeeeø)</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image45.jpeg" style="width:3.76042in;height:0.30764in" /></p>
# <p>axis=Ø)</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image46.jpeg" style="width:0.64861in;height:0.125in" />" norm" : norm_data,</p>
# <p>"skewed" : skewed data,</p>
# <p>'uniform" :uniform data,</p>
# <p>"peaked" : peaked data})</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image47.jpeg" style="width:0.86944in;height:0.125in" /> ,</p>
# <p>figsize=(le, IØ), xlim=(-5,5) );</p></td>
# <td>,</td>
# </tr>
# </tbody>
# </table>
#
# In \[52\] :
#
# —4—22
#
# In \[53\] : data df.skew()
#
# |              |                                                                    |
# |--------------|--------------------------------------------------------------------|
# | Out \[53\] : | norm -e. 06971                                                     |
# |              | s kewed 1 .628346 uniform e. 01996 peaked -e.ê26212 dtype: float64 |
#
# In \[54\] : data df.kurt()
#
# |              |         |            |
# |--------------|---------|------------|
# | Out \[54\] : | norm    | -e. e2eege |
# |              | skewed  | 1.451278   |
# |              | uniform | -1.2e8191  |
# |              | peaked  | 2 .90443   |
#
# dtype: float64
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image48.jpeg" style="width:0.32153in;height:0.125in" />
# df.isnull()
#
# Out\[55\] : RowNumber Customerld Surname CreditScore Geography Gender
# Age Tenure Balance NumOfProducts HasCrCard IsActiveMember Estir
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image49.jpeg" style="width:9.64306in;height:0.21597in" />
#
# |      |       |       |       |       |       |       |       |       |       |       |       |       |
# |------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|-------|
# | 1    | False | False | False | False | False | False | False | False | False | False | False | False |
# | 2    | False | False | False | False | False | False | False | False | False | False | False | False |
# | 3    | False | False | False | False | False | False | False | False | False | False | False | False |
# | 4    | False | False | False | False | False | False | False | False | False | False | False | False |
# | 9995 | False | False | False | False | False | False | False | False | False | False | False | False |
# | 9996 | False | False | False | False | False | False | False | False | False | False | False | False |
# | 9997 | False | False | False | False | False | False | False | False | False | False | False | False |
# | 9998 | False | False | False | False | False | False | False | False | False | False | False | False |
# | 9999 | False | False | False | False | False | False | False | False | False | False | False | False |
#
# 10000 rows x 14 columns
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image50.jpeg" style="width:8.89861in;height:0.17778in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image51.jpeg" style="width:0.32153in;height:0.125in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td>sns. heatmap(df. isnull() , ytick1abe1s=Fa1se, cbar=Fa1se, cmap= ' viridis ' )</td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# \<AxesSubp10t : \>
#
# Out \[56\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image52.jpeg" style="width:5.18125in;height:5.15347in" />
#
# |                                                                                                                                                                                          |
# |------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | sns. set_style( 'whitegrid ) sns. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image53.jpeg" style="width:0.84514in;height:0.12986in" /> ' Geography' , data=df) |
#
# In \[ 57\] :
#
# \<AxesSubp10t :xlabel= ' Geography' , ylabel= ' count' \>
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image54.jpeg" />
#
# Out\[57\]
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image55.jpeg" />8<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image56.jpeg" style="width:5.64722in;height:3.91875in" />
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image57.jpeg" />France
# Spain Germany
#
# Geography
#
# In \[ 58\] : sns. set_style( 'whitegrid ' ) sns. countplot(x= '
# Geography' , hue='Gender' ,data=df, palette=' RdBu r' )
#
# <table>
# <tbody>
# <tr class="odd">
# <td>France</td>
# <td><p>Spain</p>
# <p>Geography</p></td>
# <td>Germany</td>
# </tr>
# </tbody>
# </table>
#
# \<AxesSubp10t :xlabel= ' Geography' , ylabel= ' count' \> OUt\[58\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image58.jpeg" style="width:5.77708in;height:4.02431in" />
#
# In \[ 59\] : sns. set_style( 'whitegrid ) sns. countplot(x= ' Geography'
# , hue: ' Gender' ,data=df, palette: ' rainbow' )
#
# \<AxesSubp10t :xlabel= ' Geography' , ylabel= ' count' \> Out \[59\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image59.jpeg" style="width:5.77708in;height:4.02431in" />
#
# France Spain Germany
#
# Geography
#
# In<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image60.jpeg" style="width:0.26389in;height:0.125in" />sns.
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image61.jpeg" style="width:0.82153in;height:0.125in" />
# ' Age '
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image62.jpeg" style="width:0.74931in;height:0.125in" />kde=Fa1se,
# color= ' darkblue' , bins=4Ø)
#
# C: U\\anaconda3\\1ib\\site-packages\\seaborn\\distributions.py:2619:
# FutureWarning: is a deprecated fu nction and will be removed in a future
# version. Please adapt your code to use either
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image63.jpeg" style="width:0.62917in;height:0.125in" />
# (a figure-level function with sim ilar flexibility) or • histplot• (an
# axes-level function for histograms) . warnings . warn(msg,
# FutureWarning) \<AxesSubp10t :xlabel= ' Age ' \> Out :
#
# BOO60040020040.301000
#
# 20 50 60 70 80 90 Age
#
# <table>
# <tbody>
# <tr class="odd">
# <td>' Age' ] <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image64.jpeg" style="width:0.63403in;height:0.125in" /></td>
# <td>color= ' darkgreen' , alpha=e. 3)</td>
# </tr>
# <tr class="even">
# <td><p>&lt;AxesSubp10t : &gt;</p>
# <p>1400</p>
# <p>1200</p>
# <p>1000</p>
# <p>BOO</p>
# <p>600</p>
# <p>400</p>
# <p>200</p></td>
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image65.jpeg" style="width:5.37361in;height:4.06806in" /></td>
# </tr>
# <tr class="odd">
# <td>sns. countplot(x= ' NumOfProducts ,data=df)</td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# Out \[61\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image66.jpeg" style="width:0.26389in;height:0.125in" />
#
# \<AxesSubp10t
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image67.jpeg" style="width:0.50903in" />
# ' NumOfProducts' , ylabel= ' count \>
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image68.jpeg" style="width:0.56181in;height:0.12014in" />
#
# Out \[62\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image69.jpeg" style="width:5.80139in;height:4.07222in" />
#
# NumOfProducts
#
# |                                                                                                                                                                            |
# |----------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | ' Age ' \] <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image70.jpeg" style="width:0.80694in;height:0.125in" /> ' pink ' , bins=4e, figsize=(8,4)) |
#
# In \[63\] :
#
# |              |                    |
# |--------------|--------------------|
# | Out \[63\] : | \<AxesSubp10t : \> |
#
# 1000BOO600400200
#
# |                                                                                                                                                                                                                                                                                                                                                                                 |
# |---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | import cufflinks as cf cf. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image71.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image72.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image73.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image74.jpeg" /> |
#
# In \[64\] :
#
# |                                                                                                                                                                                                                                                                                                 |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | df\[ Age' <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image75.jpeg" style="width:0.94583in;height:0.125in" /> ' hist ' , bins=3ê, color—<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image76.jpeg" style="width:0.55208in;height:0.12986in" /> |
#
# In \[65\] :
#
# |              |                                                                                                |
# |--------------|------------------------------------------------------------------------------------------------|
# | In \[66\] :  | plt.figure(figsize=(12, 7)) sns. boxplot(x= ' Gender' ,y= ' Age ' , data=df,palette= winter' ) |
# | Out \[66\] : | \<AxesSubp10t:x1abe1= ' Gender' , ylabel= ' Age ' \>                                           |
#
# Female
#
# Gender
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>def impute_age(cols) :</p>
# <p>Age = cols[Ø]</p>
# <p>Pc lass cols [1]</p>
# <p>if pd.isnu11(Age) :</p>
# <p>if Pc lass <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image77.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image78.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image79.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image80.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image81.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image82.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image83.jpeg" />return 37</p>
# <p>el if Pc lass return 29</p>
# <p>else:</p>
# <p>return 24</p>
# <p>else:</p>
# <p>return Age</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[67\] :
#
# In \[68\] : sns. heatmap(df. isnull ( ) , ytick1abe1s=Fa1se, cbar=Fa1se,
# cmap= ' viridis ' )
#
# \<AxesSubp10t : \>
#
# Out \[68\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image84.jpeg" style="width:5.18125in;height:5.05208in" />
#
# |                                          |           |     |        |         |               |           |                |                 |
# |------------------------------------------|-----------|-----|--------|---------|---------------|-----------|----------------|-----------------|
# | df.drop( 'Gender' ,axis=l, inp1ace=True) |           |     |        |         |               |           |                |                 |
# |                                          |           |     |        |         |               |           |                |                 |
# | df.head()                                |           |     |        |         |               |           |                |                 |
# | RowNumber Customerld Surname CreditScore | Geography | Age | Tenure | Balance | NumOfProducts | HasCrCard | IsActiveMember | EstimatedSalary |
#
# ln \[69\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image85.jpeg" style="width:0.56667in;height:0.125in" />
#
# ln \[79\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image86.jpeg" />
# 1 5634602 Hargrave 619 France 42 2 0.00 1 1 10134888 1 2 1 5647311 Hill
# 608 Spain 41 1 8380786 1 11254258 2 3 15619304 Onio 502 France 42 8
# 159660.80 3 1 113931.57 3 4 15701354 Boni 699 France 39 1 0.00 2 9382663
# 4 5 1 5737888 Mitchell 850 Spain 43 2 12551082 1 79084.1 c
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image87.jpeg" style="width:9.44097in;height:0.17778in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image88.jpeg" style="width:0.32153in;height:0.125in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td>df. info()</td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# «lass 'pandas.core.frame.DataFrame'\> Rangelndex: løeøe entries, to 9999
# Data columns (total 13 columns) :
#
# Column Non-Nu11 Count Dtype
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image89.jpeg" style="width:2.79931in" />
#
# |     |                 |       |          |         |
# |-----|-----------------|-------|----------|---------|
# |     | RowNumber       | leøeø | non-null | int64   |
# | 1   | Customerld      | leøeø | non-null | int64   |
# | 2   | Surname         | leøeø | non-null | object  |
# | 3   | CreditScore     | løøeø | non-null | int64   |
# | 4   | Geography       | leeeø | non-null | object  |
# | 5   | Age             | leeeø | non-null | int64   |
# | 6   | Tenure          | leøeø | non-null | int64   |
# | 7   | Balance         | leeeø | non-null | float64 |
# | 8   | NumOfProducts   | løøeø | non-null | int64   |
# | 9   | HasCrCard       | leøeø | non-null | int64   |
# |     | IsActiveMember  | leøeø | non-null | int64   |
# | 11  | EstimatedSa1ary | leeeø | non-null | float64 |
# | 12  | Exited          | løøeø | non-null | int64   |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>pd . get_dummies</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image90.jpeg" style="width:1.32014in;height:0.56181in" /></p>
# <p>1</p>
# <p>2</p>
# <p>3</p>
# <p>4</p></td>
# <td><p>Spain</p>
# <p>0</p>
# <p>0</p>
# <p>0</p>
# <p>O</p>
# <p>O</p></td>
# <td><p>(df[ ' Geography ' ] , drop_first=True) . head()</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image91.jpeg" style="width:1.76736in" /></p>
# <p>0</p>
# <p>0 o</p>
# <p>1</p></td>
# </tr>
# <tr class="even">
# <td>cif. info</td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# dtypes: float64(2), int64(9), object(2) memory usage: 1Ø15.8+ KB ln
# \[72\] :
#
# Out \[72\] : ln \[73\] :
#
# \<bound method DataFrame. info of RowNumber Customerld Surname
# CreditScore Geography Age Tenure
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image92.jpeg" style="height:0.11528in" />
#
# Out \[73\] :
#
# 1 1563402 Hargrave 619 France 42 2
#
# -   2 15647311 Hill 668 Spain 41 1
#
# -   3 15619364 Onio 562 France 42 8 3 4 157Ø1354 Boni 699 France 39 1
#
# 4 5 15737888 Mitchell 89 Spain 43 2
#
# -   9996 1506229 Obijiaku 771 France 39 5
#
# -   9997 15569892 Johnstone 516 France 35 9997 9998 15584532 Liu 769
#     France 36 7 9998 9999 15682355 Sabbatini 772 Germany 42 3
#
# 9999 løeøe 15628319 Walker 792 France 28 4
#
# Balance NumOfProducts HasCrCard IsActiveMember EstimatedSa1ary
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image93.jpeg" style="height:0.11528in" />ø.øe
# 1 1 1 191348.88 1 8307 .86 1 1 112542. 58
#
# -   159666\. O 3 1 e 113931.57
#
# -   e\. ee 2 e 93826.63
#
# -   12551ø.82 1 1 1
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image94.jpeg" style="width:0.58611in" />
#
# 9995 ø.øe 2 1 9627e .64 9996 57369 .61 1 1 1 lei699.77 9997 ø.øe 1 1
# 42e85.58
#
# 9998 75@75.31 2 1 e 92888.52 9999 13õ142 .79 1 1 3819e.78
#
# Exited 1 1 2 1
#
# 3
#
# 4
#
# 9995
#
# 9996
#
# -   1
#
# -   1
#
# 9999
#
# \[løeøø rows x 13 columns\] \>
#
# <table>
# <tbody>
# <tr class="odd">
# <td></td>
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image95.jpeg" style="width:0.26389in;height:0.125in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td>pd.getsex = pd. get embark</td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image96.jpeg" style="width:0.56181in;height:0.125in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image97.jpeg" style="width:0.70625in;height:0.22083in" /> ' Age</td>
# <td>, 'HasCrCard' , 'Surname' , 'Customerld' ],axis=l, inp1ace=True)</td>
# </tr>
# </tbody>
# </table></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image98.jpeg" style="width:0.26389in;height:0.12986in" />
# df.head()
#
# Out \[76\] : RowNumber CreditScore Geography Tenure Balance
# NumOfProducts IsActiveMember EstimatedSalary Exited
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image99.jpeg" style="width:7.63056in;height:0.21111in" />
#
# |     |     |     |        |     |           |     |     |           |                                                                                        |
# |-----|-----|-----|--------|-----|-----------|-----|-----|-----------|----------------------------------------------------------------------------------------|
# | 1   | 2   | 608 | Spain  | 1   | 83807.86  |     | 1   | 112542.58 |                                                                                        |
# | 2   | 3   | 502 | France | 8   | 159660.80 | 3   |     | 113931.57 | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image100.jpeg" /> |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><ol type="1">
# <li><p>4</p></li>
# <li><p>5</p></li>
# </ol></td>
# <td><p>699</p>
# <p>850</p></td>
# <td>France 1 Spain 2</td>
# <td><p>0.00</p>
# <p>125510.82</p></td>
# <td>2</td>
# <td></td>
# <td><p>93826.63</p>
# <p>79084.10</p></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>train pd. concat( [df, sex, embark] , axis=l)</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>train. head()</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>RowNumber CreditScore Geography Tenure</td>
# <td>Balance</td>
# <td>NumOfProducts</td>
# <td>IsActiveMember</td>
# <td>EstimatedSalary</td>
# <td>Exited 19 212692.97 212696.32</td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# out
# \[78\]<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image101.jpeg" />
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image102.jpeg" style="width:0.26389in;height:0.125in" />
#
# 619 France 2 0.00 1 101348.88
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image103.jpeg" />
# 0 0
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image104.jpeg" style="width:0.26389in;height:0.125in" />
#
# 1.  2 608 Spain 1 83807.86 1 112542.58 O O
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image105.jpeg" />
#
# 2.  3 502 France 8 159660.80 3 113931.57
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image106.jpeg" />
#
# 3.  4 699 France 1 0.00 2 0 93826.63 o o
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image107.jpeg" />
#
# 4.  5 850 Spain 2 125510.82 1 79084.10 o o
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image108.jpeg" />
#
# 5.  rows x 6459 columns
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image109.jpeg" style="width:6.53125in;height:0.17292in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image110.jpeg" style="width:0.26389in;height:0.12014in" /></td>
# <td><table>
# <tbody>
# <tr class="odd">
# <td>data <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image111.jpeg" style="width:1.45486in;height:0.125in" /> 1, 15, 2, 2, mean - np.mean(data) std - np.std(data) print( 'mean of the dataset is ' mean) print( ' std. deviation is ' , std)</td>
# <td>2,</td>
# <td>3,</td>
# <td>1,</td>
# <td>1,</td>
# <td>2]</td>
# </tr>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
#
# mean of the dataset is 2.6666666666666665 std. deviation is
# 3.3598941782277745
#
# |                                  |
# |----------------------------------|
# | threshold outlier for i in data: |
#
# In<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image112.jpeg" style="width:0.26389in" />
#
# |                                                                                          |          |
# |------------------------------------------------------------------------------------------|----------|
# | z = (i-mean)/std if z \> threshold: outlier. append(i) print( 'outlier in dataset is ' , | outlier) |
#
# outlier in dataset is \[15\]
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image113.jpeg" style="width:0.26389in" />
# sorted(data)
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image114.jpeg" style="width:1.84861in;height:0.11042in" />2,
# 2, 3, 3, 15\]
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image115.jpeg" style="width:2.05069in" />
#
# Out \[81\] :
#
# |                       |                                   |
# |-----------------------|-----------------------------------|
# | quantilel, quanti1e3= | np . percentile(data, \[25, 75\]) |
#
# In \[82\] :
#
# |             |                              |
# |-------------|------------------------------|
# | In \[83\] : | print (quantilel, quanti1e3) |
#
# |                                                                                                                      |                       |
# |----------------------------------------------------------------------------------------------------------------------|-----------------------|
# | I.e 2 .6                                                                                                             |                       |
# | iqr_va1ue=quanti1e3-quanti1e1 print(iqr_value)                                                                       |                       |
# | I.e                                                                                                                  |                       |
# | lower bound val - quantilel - (1 . 5 \* upper bound val - quanti1e3 +(1.5 \* print (lower bound val,upper_bound val) | iqr_value) iqr value) |
#
# In \[84\] :
#
# In \[85\] :
#
# -e. 5 3 5
#
# <table>
# <tbody>
# <tr class="odd">
# <td>df=pd. read_csv( 'Churn Modelling. ) df.head() numeric ' RowNumber' , 'Customerld' , categorical <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image116.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image117.jpeg" /> 'Surname' , 'Geography' ,</td>
# <td><p>' CreditScore' ,</p>
# <p>'Gender' ]]</p></td>
# <td>' Age' ,</td>
# <td>'Tenure'</td>
# <td>'Balance' ,</td>
# <td>' NumOfProducts ' , 'HasCrCard' , IsActiveMemb(</td>
# </tr>
# </tbody>
# </table>
#
# In \[86\] :
#
# In \[87\] : numeric . head()
#
# Out \[87\] : RowNumber Customerld CreditScore Age Tenure Balance
# NumOfProducts HasCrCard IsActiveMember EstimatedSalary Exited
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>1 5634602</p>
# <ol type="1">
# <li><p>2 1 5647311</p></li>
# <li><p>3 15619304</p></li>
# <li><p>4 15701354</p></li>
# <li><p>5 15737888</p></li>
# </ol>
# <p>categorical . head()</p></td>
# <td><p>619</p>
# <p>608</p>
# <p>502</p>
# <p>699</p>
# <p>850</p></td>
# <td><p>42</p>
# <p>41</p>
# <p>42</p>
# <p>39</p>
# <p>43</p></td>
# <td><p>2</p>
# <p>1</p>
# <p>8</p>
# <p>2</p></td>
# <td><p>0.00</p>
# <p>83807.86</p>
# <p>159660.80</p>
# <p>0.00</p>
# <p>125510.82</p></td>
# <td><p>1</p>
# <p>1</p>
# <p>3</p>
# <p>2</p>
# <p>1</p></td>
# <td><p>0</p>
# <p>0</p></td>
# <td><p>101348.88</p>
# <p>112542.58</p>
# <p>113931.57</p>
# <p>93826.63</p>
# <p>79084.10</p></td>
# <td><p>1</p>
# <p>0</p>
# <p>0</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[88\] :
#
# |              |                   |        |
# |--------------|-------------------|--------|
# | Out \[88\] : | Surname Geography | Gender |
#
# |     |          |        |        |
# |-----|----------|--------|--------|
# | O   | Hargrave | France | Female |
# | 1   | Hill     | Spain  | Female |
# | 2   | Onio     | France | Female |
# | 3   | Boni     | France | Female |
# | 4   | Mitchell | Spain  | Female |
#
# In \[89\] : print(df\[ 'Surname' \] . unique()) print(df\[ ' Geography'
# \] . unique()) print(df\[ 'Gender' \] . unique())
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>[ ' Hargrave ' ' Hill ' 'Onio'</p>
# <p>[ ' France' 'Spain' ' Germany' <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image118.jpeg" style="height:0.12986in" /></p>
# <p>[ ' Female' 'Male' ]</p></td>
# <td>' Kashiwagi '</td>
# <td>' Aldridge '</td>
# <td>' Burbidge ' ]</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td>from sklearn.preprocessing import LabelEncoder marry encoder - Label Encoder()</td>
# </tr>
# <tr class="even">
# <td></td>
# </tr>
# <tr class="odd">
# <td><p>residence encoder — LabelEncoder() residence values residence_encoder. fit transform(df categorical [ 'Geography' ] )</p>
# <p>print("Before Encoding: " , <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image119.jpeg" style="width:1.02778in;height:0.12986in" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image120.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image121.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image122.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image123.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image124.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image125.jpeg" /> ' Geography' ] [ : 5] ) ) print ("After Encoding: " , residence_values[ : 5] ) print ("The inverse from the encoding result : " residence encoder. inverse transform(residence values [ : 5] ) )</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[9Ø\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image126.jpeg" style="width:0.26389in;height:0.125in" />
#
# Before Encoding: \[ ' France ' Spain' France ' 'France' 'Spain ' \]
#
# After Encoding: \[6 2 2\]
#
# The inverse from the encoding result: \[ ' France' 'Spain' 'France'
# France' ' Spain ' \]
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>from sklearn.preprocessing import OneHotEncoder import numpy as np</p>
# <p>gender encoder = OneHotEncoder() gender reshaped np. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image127.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image128.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image129.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image130.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image131.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image132.jpeg" style="height:0.125in" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image133.jpeg" style="width:1.09514in;height:0.12986in" /> 'Gender' ] ) . reshape(-l, gender values - gender_encoder. fit transform(gender_reshaped)</p>
# <p>print(df_categorical[ 'Gender' print()</p></td>
# <td>1)</td>
# </tr>
# </tbody>
# </table>
#
# In \[95\] :
#
# print(gender values.toarray( ) \[ : 5\] )
#
# print() print(gender encoder. inverse_transform(gender values) \[ :5\] )
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image134.jpeg" />
# Female
#
# 1.  Female
#
# 2.  Female
#
# 3.  Female
#
# 4.  Female
#
# Name : Gender, dtype : object
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image135.jpeg" style="width:0.62917in;height:0.80694in" />
#
# \[ \[ 'Female' \]
#
# \[ '
# Female<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image136.jpeg" style="height:0.125in" />
#
# \[ 'Female' \]
#
# \[ '
# Female<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image137.jpeg" style="height:0.12986in" />
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image138.jpeg" style="height:0.12986in" />Female'
# \]\]
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>smoke encoder = OneHotEncoder() smoke reshaped np.array(df_categorical[ Surname ' ] ) . reshape(-l, smoke values - smoke_encoder.fit transform(smoke_reshaped)</p>
# <p>print(df categorical [ 'Surname' print() print (smoke values.toarray() [ :5] ) print() print(smoke encoder. inverse_transform(smoke values) [ :5] )</p></td>
# <td>1)</td>
# </tr>
# </tbody>
# </table>
#
# In \[96\] :
#
# |                                                                                        |          |         |        |
# |----------------------------------------------------------------------------------------|----------|---------|--------|
# | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image139.jpeg" /> | Hargrave |         |        |
# | 1                                                                                      | Hill     |         |        |
# | 2                                                                                      | Onio     |         |        |
# | 3                                                                                      | Boni     |         |        |
# | 4                                                                                      | Mitchell |         |        |
# | Name:                                                                                  | Surname, | dtype : | object |
#
# e.e.\[e.<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image140.jpeg" style="width:0.64306in" />
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image141.jpeg" style="width:0.41319in" />
#
# \[e.
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image142.jpeg" style="width:0.63889in" />\[e.<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image143.jpeg" style="width:0.63889in" />
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image144.jpeg" style="width:0.72014in;height:0.80694in" />
#
# \[ \[ 'Hargrave' \]
#
# \[ ' Hill ' \]
#
# \[ ' Onio ' \]
#
# \[ ' Boni ' \]
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>work encoder OneHotEncoder() work_reshaped np. array(df_categorical[ ' Geography ' ] ) . reshape(-l, work values = work encoder.fit transform(work reshaped)</p>
# <p>print(df_categorical[ 'Geography' ] [ : 5] ) print() print(work values.toarray() [ : 5] ) print() print(work encoder. inverse transform(work_va1ues) [ :5])</p></td>
# <td>1)</td>
# </tr>
# </tbody>
# </table>
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image145.jpeg" style="height:0.12986in" />
# 'Mitchell ' \] \] In \[97\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image146.jpeg" />
# France 1 Spain
#
# 1.  France
#
# 2.  France
#
# 3.  Spain
#
# Name: Geography, dtype: object
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image147.jpeg" style="width:0.77292in;height:0.125in" />
#
# \[6 . e. 1 . \] \[1 .
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image148.jpeg" style="width:0.41806in;height:0.30278in" />
#
# \[1 .
#
# \[e. e. 1. \] \]
#
# \[ \[ ' France' \]
#
# \[ 'Spain' \]
#
# \[ ' France' \]
#
# \[ ' France' \] \[ 'Spain ' \] \]
#
# |                         |                                                         |                  |
# |-------------------------|---------------------------------------------------------|------------------|
# | categorical categorical | encoded pd. get dummies(df categorical, encoded. head() | drop first=True) |
#
# In \[98\] :
#
# Out \[98\] : Surname Abbie Surname Abbott Surname Abdullah Surname
# Abdulov Surname Abel Surname_Abernathy Surname Abramov Surname Abramova
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image149.jpeg" style="width:9.64792in;height:0.29306in" />
#
# 1.  0 0 0 0 0 0
#
# 2.  0 0 0 0 0
#
# 3
#
# 4
#
# 5 rows x 2934 columns
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image150.jpeg" style="width:4.34167in;height:0.17292in" />
#
# |                                                                       |               |           |                |                 |                |
# |-----------------------------------------------------------------------|---------------|-----------|----------------|-----------------|----------------|
# | new = pd. concat( \[df_numeric, df_categorical encoded\], new. head() | axis-I)       |           |                |                 |                |
# | RowNumber Customerld CreditScore Age Tenure Balance                   | NumOfProducts | HasCrCard | IsActiveMember | EstimatedSalary | Surname Zotova |
#
# In \[99\] :
#
# Out \[99\] :
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image151.jpeg" />
# 1 5634602 619 42 2 0.00 1
# 101348.88<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image152.jpeg" />
#
# 1.  2 1 5647311 608 41 1 83807.86 1 1
#     12542.58<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image153.jpeg" />
#
# 2.  3 15619304 502 42 8 159660.80 3 0 113931.57 0
#
# 3.  4 15701354 699 39 1 0.00 2 0 93826.63 0
#
# 4.  5 15737888 850 43 2 125510.82 1
#     79084.10<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image154.jpeg" />
#
# 5.  rows x 2945 columns
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image155.jpeg" style="width:5.20556in;height:0.18264in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>print(df[ "Balance" ] . min()) print(df[ "Balance" ] . max())</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image156.jpeg" style="width:0.64306in;height:0.12986in" />"Balance"] . mean())</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[ lee...
#
# 256898.69
#
# 76485.88928799961
#
# <table>
# <tbody>
# <tr class="odd">
# <td>print(df. count(Ø))</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><p>RowNumber</p>
# <p>Customerld</p>
# <p>Surname</p>
# <p>CreditScore</p>
# <p>Geography</p>
# <p>Gender</p>
# <p>Age</p>
# <p>Tenure</p>
# <p>Balance</p>
# <p>NumOfProducts</p>
# <p>HasCrCard</p>
# <p>IsActiveMember</p>
# <p>EstimatedSa1ary</p>
# <p>Exited dtype: int64</p></td>
# <td>leeee leøeø leøeø 1 eøeø leeee 1 eøeø leøeø leøeø leeee leøeø leøeø leeeø 1 eøeø leøeø</td>
# </tr>
# <tr class="odd">
# <td><p>print(df. shape)</p>
# <p>(løeøø, 14)</p></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>print(df.size)</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><p>14eøeø</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image157.jpeg" style="width:0.57639in" /></p>
# <p>X = df.iloc[ : , print (X)</p></td>
# <td><p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image158.jpeg" style="width:0.46111in" /></p>
# <p>: -1] . values</p></td>
# </tr>
# </tbody>
# </table>
#
# In \[ 191...
#
# In \[ 1Ø2...
#
# In \[10...
#
# In \[ 1Ø4...
#
# \[ \[1 1563402 ' Hargrave ' . 1 1 161348.88\]
#
# 1.  15647311
#     'Hill'<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image159.jpeg" style="width:0.17292in" />e
#     1 112542.58\]
#
# 2.  156193ê4 ' Onio
#     '<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image160.jpeg" style="width:0.17292in" />1
#     e 113931.57\]
#
# 3.  15584532 ' Liu
#     '<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image161.jpeg" style="width:0.17292in" />e
#     1 4205.58\]
#
# 4.  15682355
#     'Sabbatini'<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image162.jpeg" style="width:0.17292in" />1
#     e 92888.52\] \[løeøe 15628319 'Walker'
#     .<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image163.jpeg" style="width:0.10069in" />1
#     ø 3819ø.78\]\]
#
# |                             |               |
# |-----------------------------|---------------|
# | Y = df.iloc\[ : , print (Y) | -1\] . values |
#
# In \[ les...
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image164.jpeg" style="width:0.33611in" />1
# 1 6\]
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>'Tenure' ]] • values</p>
# <p>'Gender' ] • values fig, ax = plt.subp10ts(nc01s=2, figsize=(12,</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image165.jpeg" style="width:1.7625in;height:0.125in" /></p>
# <p>ax[l] . scatter(x[ : ,l] , y) PI t. show()</p></td>
# <td>4))</td>
# </tr>
# </tbody>
# </table>
#
# In \[ 1Ø6...
#
# MaleMale
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image166.jpeg" style="width:4.07222in;height:2.97778in" />
#
# FemaleFemale
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image167.jpeg" style="width:4.13472in;height:2.98681in" />
#
# 20 30 40 50 60 70 90 2 4 6 8 10
#
# <table>
# <tbody>
# <tr class="odd">
# <td>fig, ax = plt.subp10ts(figsize=(12, 4)) ax. <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image168.jpeg" style="width:1.03264in;height:0.125in" /> y) ax. scatter(x[ : ,l] , Y)</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><p>&lt;matp10t1ib.c011ections.PathC011ection</p>
# <p>Male</p>
# <p>Female</p></td>
# <td><p>at Øx1f62c93a4fØ&gt;</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image169.jpeg" style="width:8.93681in;height:3.15486in" /></p></td>
# </tr>
# <tr class="odd">
# <td><p>fig, ax = plt.subp10ts(figsize=(12,</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image170.jpeg" style="width:1.09028in;height:0.125in" /></p>
# <p>ax.hist(x[ : ,l] )</p></td>
# <td>4))</td>
# </tr>
# </tbody>
# </table>
#
# In \[ 1ê7... out\[1Ø7\] :
#
# In \[10...
#
# (array(\[ 413. , IBS. , 1648. leø9. , 989.
#
# out\[1Ø8\] : , , 1Ø12., 967. , 1Ø28., 1Ø25.,
#
# 1474\. \] ) , array(\[ e.
# ,<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image171.jpeg" style="width:3.69306in;height:0.125in" />
#
# \<BarContainer object of le artists \> )
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image172.jpeg" style="width:9.47986in;height:3.19861in" />
#
# |                                                                                                                                                                                                                                                                                                                                                                 |
# |-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | from sklearn.preprocessing import StandardSca1er from sklearn.preprocessing import MinMaxSca1er fig, ax = plt.subp10ts(figsize=(12, 4)) scaler - StandardSca1er() x std scaler.fit transform(x) ax.hist(x <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image173.jpeg" style="width:0.725in;height:0.12986in" />ax.hist(x_std\[ : ,l\] ) |
#
# In \[10...
#
# (array(\[ 413. , 105.
#
# out\[1Ø9\] : , 1648. , leø9. , 201. , 1995. , 1Ø25.,
#
# 1474\. \] ) ,
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image174.jpeg" style="width:0.71042in;height:0.12986in" />73331549,
# -1.38753759, -1.Ø4175968, -e. 69598177, -e. 35me386,
#
# -e. 0442596, e. 34135195, e. 68712986, 1 .0296776, 1.37868567,
#
# 1 .72446358\] ) ,
#
# \<BarContainer object of 16 artists\>)
#
# -2235
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>fig, ax - plt.subp10ts(figsize=(12, scaler - StandardSca1er() x std - scaler.fit_transform(x) ax. scatter(x y) ax. scatter(x y)</p>
# <p><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image175.jpeg" style="width:0.63403in;height:0.29306in" /></p></td>
# <td>4))</td>
# </tr>
# </tbody>
# </table>
#
# In \[ lie...
#
# \<matplotlib.collections. PathC011ection at Øx1f6458d94ØØ\> Out\[11Ø\] :
#
# -2235Male
#
# Female
#
# |                                                                                                                                              |     |
# |----------------------------------------------------------------------------------------------------------------------------------------------|-----|
# | fig, ax - plt.subp10ts(figsize=(12, scaler = MinMaxSca1er() x_minmax = scaler.fit transform(x) ax.hist(x minmax ax.hist(x_minmax \[ : ,1\] ) | 4)) |
#
# In \[111...
#
# (array(\[ 413. , 105. 1Ø48. 109. 989. 1Ø12., 967. 1ê28. , 1Ø25.,
#
# Out\[lll\] : , , , , ,
#
# 1474\. \] ) ,
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image176.jpeg" style="width:0.26875in;height:0.11042in" />6.1,
# e. 2, e. 3, e.4, 6.5, e.6, 6.7, e. 9,
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image177.jpeg" style="width:0.41319in;height:0.11042in" />\<BarContainer
# object of le artist")
#
# 0.00.20.60.8
#
# |                                                                                                                                                           |       |
# |-----------------------------------------------------------------------------------------------------------------------------------------------------------|-------|
# | fig, ax = plt.subp10ts(figsize=(12, scaler = MinMaxSca1er() x minmax = scaler.fit transform(x) ax. scatter(x_minmax y) ax. scatter(x_minmax \[ : ,1\], y) | 4\) ) |
#
# In \[ 112...
#
# \<matp10t1ib.c011ections.PathC011ection at Øx1f645a969aØ\> Out\[112\] :
#
# 02Male
#
# Female
#
# |                                                                                                                                                                                                                   |
# |-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | fig, ax - plt.subp10ts(figsize=(12, 4)) scaler = MinMaxSca1er() x_minmax = scaler.fit transform(x) ax. scatter(x minmax <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image178.jpeg" /> y) |
#
# In \[ 113...
#
# \<matp10t1ib.c011ections.PathC011ection at øx1f645a7f6aØ\> Out\[113\] :
#
# 0210Male
#
# Female
#
# In \[ 114... fig, ax - plt.subp10ts(figsize=(12, 4)) scaler =
# MinMaxSca1er() x_minmax = scaler.fit transform(x) ax.hist(x_minmax \[ :
# , e \] )
#
# Out\[114\] : , 2179. , 3629. , 1871. , 91e., 441. , 268. , 127. , 26. ,
# (array(\[ 611.
#
# array(\[e.
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image179.jpeg" style="width:3.85625in;height:0.29306in" />
#
# \<BarContainer object of le artist")
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image180.jpeg" style="width:9.47986in;height:3.20347in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>f rom sklearn.model selection import train test split from sklearn.pipeline import Pipeline from sklearn.linear model import SGDRegressor from sklearn.preprocessing import StandardSca1er from sklearn.preprocessing import MinMaxSca1er from sklearn.metrics import mean absolute error import sklearn.metrics as metrics import pandas as pd import numpy as np import matplotlib. pyplot as plt pd. read csv( 'Churn Model ling. csv' )</p>
# <p>'Tenure' ]] • values</p>
# <p>Y = 'Balance <sup>I</sup> ] . values</p>
# <p>X train, X test, Y train, Y test train test split(x,</p></td>
# <td>y)</td>
# </tr>
# </tbody>
# </table>
#
# In \[115...
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>pipeline Pipeline( [</p>
# <p>("MinMax Scaling", MinMaxSca1er()),</p>
# <p>("SGD Regression" , SGDRegressor())]) pipeline.fit()&lt; train, Y train) Y pred pipeline. predict()( test) print( 'Mean Absolute Error: mean_absolute error(Y_pred, print( 'Score' , pipeline. score()(_test, Y_test))</p></td>
# <td>Y_test) )</td>
# </tr>
# </tbody>
# </table>
#
# Mean Absolute Error: 57686. 85477211642
#
# Score 6.012166166761276297
#
# In \[ 116... import numpy as np import matplotlib. pyplot as plt import
# pandas as pd
#
# In \[ 117... dataset - pd.read_csv( 'Churn Model ling.csv' )
#
# X = dataset. iloc\[ : , : -1\] . values Y = dataset. iloc\[ : , -1\] .
# values
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>from sklearn.model selection import train_test_split</p>
# <p>X_train, X_test, y_train, y_test = train_test_split()(,</p></td>
# <td>y,</td>
# <td>test</td>
# <td>size</td>
# <td>2,</td>
# <td>random</td>
# <td>state</td>
# </tr>
# </tbody>
# </table>
#
# In \[118...
#
# In \[ 119... print (X)
#
# \[ \[1 1563402 '
# Hargrave<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image181.jpeg" style="width:0.31667in;height:0.10069in" />1
# 1 1ê1348.88\]
#
# 1.  15647311 'Hill
#     '<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image182.jpeg" style="width:0.48958in" />112542.
#     58\]
#
# 2.  156193ê4 ' Onio
#     '<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image183.jpeg" style="width:0.48958in" />113931.
#     57\]
#
# 3.  15584532 ' Liu
#     '<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image184.jpeg" style="width:0.17292in" />e
#     1 42ê85.58\]
#
# 4.  15682355
#     'Sabbatini'<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image185.jpeg" style="width:0.17292in" />1
#     e 92888.52\] \[løeøe 15628319 'Walker'
#     .<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image186.jpeg" style="width:0.10069in" />1
#     <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image187.jpeg" />
#     38196.78\] \]
#
# In \[120..
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image188.jpeg" style="width:0.77292in;height:0.50903in" />
#
# 1 1 e\]
#
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                                                                                                               |
# |----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | from sklearn . compose import Column Transformer from sklearn.preprocessing import OneHotEncoder ct - <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image189.jpeg" style="width:0.58611in" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image190.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image191.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image192.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image193.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image194.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image195.jpeg" /> <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image196.jpeg" style="width:1.39722in;height:0.12986in" /> 'encoder' X = np.array(ct.fit<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image197.jpeg" />transform()()) | OneHotEncoder() , <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image198.jpeg" style="height:0.125in" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image199.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image200.jpeg" style="height:0.125in" /> remainder--'passthrough' ) |
#
# In \[ 121...
#
# In \[ 122... print(X)
#
# |              |                                                                                                                                                                                    |                                                                                        |     |               |
# |--------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------|-----|---------------|
# | \[ \[I.e e.e | e.e . <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image201.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image202.jpeg" /> | 1                                                                                      | 1   | 161348.88\]   |
# | \[e.ø e.e    | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image203.jpeg" style="width:0.48472in" />                                                                     | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image204.jpeg" /> | 1   | 112542\. 58\] |
# | \[I.e e.e    | e.ø . <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image205.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image206.jpeg" /> | 1                                                                                      | e   | 113931\. 57\] |
# | \[I.e e.e    | e.e . .                                                                                                                                                                            | e                                                                                      | 1   | 4205.58\]     |
# | \[e.e I.e    | e.e . <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image207.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image208.jpeg" /> | 1                                                                                      | e   | 92888\. 52\]  |
# | \[I.e ø.e    | e.ø . . .                                                                                                                                                                          | 1                                                                                      | e   | 3819th 78\]\] |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>from sklearn.preprocessing import LabelEncoder</p>
# <p>— Label Encoder() y = le.fit_transform(y)</p></td>
# </tr>
# <tr class="even">
# <td></td>
# </tr>
# <tr class="odd">
# <td>print(y)</td>
# </tr>
# </tbody>
# </table>
#
# In \[ 123...
#
# In \[ 124...
#
# |                                                                                                                |         |
# |----------------------------------------------------------------------------------------------------------------|---------|
# | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image209.jpeg" style="width:0.33611in" /> | 1 1 6\] |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>from sklearn . model_selection import train_test_split</p>
# <p>X train, X test, y_train, y_test = train test_split()(, y, test_ size</p></td>
# <td>2,</td>
# <td>random state</td>
# </tr>
# <tr class="even">
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>print(X train)</td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# In \[ 125...
#
# In \[ 126...
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image210.jpeg" style="width:0.12014in" />e
# I.e e
# e<img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image211.jpeg" style="width:0.17292in" />e
# 1 124749.68\]
#
# <table>
# <tbody>
# <tr class="odd">
# <td><ol type="1">
# <li><p>. e e.e e e</p></li>
# </ol>
# <p>[e.e I.e e e</p>
# <p>[1.e e.e e.e .</p>
# <p>[1.e e.e e.e . . .</p>
# <p>[e.e I.e e.ø . . .</p></td>
# <td><p>e 1</p>
# <p>1</p>
# <p>1</p>
# <p>1</p></td>
# <td><p>e 1</p>
# <p>1 1 e</p></td>
# <td><p>41164.82]</p>
# <p>4579.21]</p>
# <p>92Ø27.69]</p>
# <p>161168.9]</p>
# <p>33462.94] ]</p></td>
# </tr>
# <tr class="even">
# <td>print(X test)</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# In \[ 127...
#
# |                                                                                                                                                                                                                                                                                  |     |     |               |
# |----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----|-----|---------------|
# | <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image212.jpeg" style="width:1.21944in;height:0.125in" />                                                                                                                                                    | 1   | 1   | 97õ57.28\]    |
# | \[I.e e.e e.e . . .                                                                                                                                                                                                                                                              | 1   | e   | 6652601\]     |
# | \[I.e e.e e.e .                                                                                                                                                                                                                                                                  | e   | 1   | 96537.47\]    |
# | \[e.e e.e 1 ø                                                                                                                                                                                                                                                                    | ø   | 1   | 161571.79\]   |
# | \[e.ø I.e e.ø . . .                                                                                                                                                                                                                                                              | 1   | 1   | 165257.31\]   |
# | \[9.e I.e e.ø <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image213.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image214.jpeg" /><img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image215.jpeg" /> | 1   | 1   | 49e25.79\] \] |
#
# In \[ 128... print(y_train)
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image216.jpeg" style="width:1.22431in;height:0.12986in" />
#
# |              |               |
# |--------------|---------------|
# | In \[ 129... | print(y_test) |
#
# <img src="attachment:vertopal_bf2fadd16fd14dfa87088f71fdf7858b/media/image217.jpeg" style="width:1.22431in;height:0.125in" />
